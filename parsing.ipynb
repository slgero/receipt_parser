# %%
from bs4 import BeautifulSoup
import requests as req
import re
import numpy as np
import pandas as pd

# %%
url = 'https://www.perekrestok.ru/catalog/moloko-syr-yaytsa/tvorog-syrki'

# %%
url = 'https://www.perekrestok.ru/catalog/moloko-syr-yaytsa/tvorog-syrki/danon-tvorog-myagkiy-5-170g--306003'

# %%
'https://www.perekrestok.ru' + '/catalog/moloko-syr-yaytsa/tvorog-syrki/selo-zel-tvorog-5-500g--331906'
# Out:
# 'https://www.perekrestok.ru/catalog/moloko-syr-yaytsa/tvorog-syrki/selo-zel-tvorog-5-500g--331906'

# %%
resp = req.get(url)

# %%
soup = BeautifulSoup(resp.text, 'lxml')

# %%
soup.find_all(class_='js-catalog-product _additionals xf-catalog__item')[1].find(class_ = 'xf-product-picture__link js-product__image').get('href')
# Out:
# '/catalog/moloko-syr-yaytsa/tvorog-syrki/selo-zel-tvorog-5-500g--331906'

# %%
data
# Out:
# [['Danone'],
#  ['Россия'],
#  ['Творог'],
#  ['Мягкий'],
#  ['Без добавок'],
#  ['5 %'],
#  ['170 г'],
#  ['Пластиковый стакан'],
#  ['Творог обезжиренный, сливки']]

# %%
data = []

# %%
rows = table.find_all('tr')

# %%
table_body = res.find('tbody')

# %%
table_body

# %%
d = {}
[d.setdefault(key, None) for key in ['Производитель', 'Торговая марка', 'Вес', 'Жирность']]
d
# Out:
# {'Производитель': None, 'Торговая марка': None, 'Вес': None, 'Жирность': None}

# %%
url = 'https://www.perekrestok.ru/catalog/moloko-syr-yaytsa/tvorog-syrki'

# %%
url.split('/')[-1]
# Out:
# 'tvorog-syrki'

# %%
print(f'Get data about {url.split("/")[-1]}')
# Out:
# Get data about tvorog-syrki

# %%
base_url = 'https://www.perekrestok.ru/catalog/moloko-syr-yaytsa/tvorog-syrki'
MAIN_URL = 'https://www.perekrestok.ru'
columns=['Производитель', 'Торговая марка', 'Вес', 'Жирность']
result = pd.DataFrame(columns=columns)
goods = dict()
[goods.setdefault(key, None) for key in columns]

response = req.get(base_url)
print(f'Get data about {base_url.split("/")[-1]}')
soup = BeautifulSoup(response.text, 'lxml')
for good in soup.find_all(class_='js-catalog-product _additionals xf-catalog__item'):
    url = good.find(class_ = 'xf-product-picture__link js-product__image').get('href')
    url = MAIN_URL + url
    resp = req.get(url)
    break
    soup_ = BeautifulSoup(resp.text, 'lxml')
    table = soup_.find('table', attrs={'class':'xf-product-info__table xf-product-table'})
    rows = table.find_all('tr')
# Out:
# Get data about tvorog-syrki

# %%
url
# Out:
# 'https://www.perekrestok.ru/catalog/moloko-syr-yaytsa/tvorog-syrki/danon-tvorog-myagkiy-5-170g--306003'

# %%
soup_ = BeautifulSoup(resp.text, 'lxml')

# %%
table = soup_.find('table', attrs={'class':'xf-product-info__table xf-product-table'})

# %%
rows = table.find_all('tr')

# %%
rows
# Out:
# [<tr class="xf-product-table__row">
#  <th class="xf-product-table__col-header">
#                                              Производитель
#                                                                                      </th>
#  <td class="xf-product-table__col">
#
#                                                                                                                                      Danone
#                                                                                                                                                                                                                                                                      </td>
#  </tr>,
#  <tr class="xf-product-table__row">
#  <th class="xf-product-table__col-header">
#                                              Страна
#                                                                                      </th>
#  <td class="xf-product-table__col">
# ...

# %%
def parse_info_about_good(base_url: str):
    MAIN_URL = 'https://www.perekrestok.ru'
    columns=['Производитель', 'Торговая марка', 'Вес', 'Жирность']
    result = pd.DataFrame(columns=columns)
    goods = dict()
    [goods.setdefault(key, None) for key in columns]
    
    response = req.get(base_url)
    print(f'Get data about {base_url.split("/")[-1]}')
    soup = BeautifulSoup(response.text, 'lxml')
    for good in soup.find_all(class_='js-catalog-product _additionals xf-catalog__item'):
        url = good.find(class_ = 'xf-product-picture__link js-product__image').get('href')
        url = MAIN_URL + url
        resp = req.get(url)
        
        soup_ = BeautifulSoup(resp.text, 'lxml')
        table = soup_.find('table', attrs={'class':'xf-product-info__table xf-product-table'})
        if table:
            rows = table.find_all('tr')
            for row in rows:
                key = row.find_all(class_="xf-product-table__col-header")[0].text.strip()
                value = row.find_all('td')[0].text.strip()
                if key == 'Объём':
                    key = 'Вес'
                if key not in columns:
                    continue
                goods[key] = value

            result = pd.concat([result, pd.DataFrame.from_dict(goods, orient='index').T])
    return result

# %%
df = parse_info_about_good('https://www.perekrestok.ru/catalog/moloko-syr-yaytsa/tvorog-syrki')
# Out:
# Get data about tvorog-syrki

# %%
df
# Out:
# 24

# %%
result
# Out:
#   Производитель Торговая марка    Вес Жирность
# 0        Danone           None  170 г      5 %

# %%
pd.concat([result, pd.DataFrame.from_dict(goods, orient='index').T])
# Out:
#   Производитель Торговая марка    Вес Жирность
# 0        Danone           None  170 г      5 %

# %%
list(pd.DataFrame.from_dict(good, orient='index').T.columns)
# Out:
# ['Производитель',
#  'Страна',
#  'Тип',
#  'Вид творога',
#  'Вкус',
#  'Жирность',
#  'Вес',
#  'Тип упаковки',
#  'Состав',
#  'Энергетическая ценность',
#  'Белки',
#  'Жиры',
#  'Углеводы',
#  'Температура хранения мин.',
#  'Температура хранения макс.',
#  'Срок хранения']

# %%
table = soup.find('table', attrs={'class':'xf-product-info__table xf-product-table'})

# %%
table_body

# %%
rows[0]
# Out:
# <tr class="xf-product-table__row">
# <th class="xf-product-table__col-header">
#                                             Производитель
#                                                                                     </th>
# <td class="xf-product-table__col">
#
#                                                                                                                                     Danone
#                                                                                                                                                                                                                                                                     </td>
# </tr>

# %%
asoup.find(class_='xf-product-info__table xf-product-table')
# Out:
# <table class="xf-product-info__table xf-product-table">
# <tr class="xf-product-table__row">
# <th class="xf-product-table__col-header">
#                                             Производитель
#                                                                                     </th>
# <td class="xf-product-table__col">
#
#                                                                                                                                     Danone
#                                                                                                                                                                                                                                                                     </td>
# </tr>
# <tr class="xf-product-table__row">
# <th class="xf-product-table__col-header">
#                                             Страна
#                                                                                     </th>
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ru">
# <head>
# <meta charset="utf-8"/>
# <link href="/favicon.ico" rel="shortcut icon" sizes="16x16 32x32"/>
# <title>Купить Творог Danone мягкий 5% 170г с доставкой на дом по цене 45.90 руб в интернет-магазине Перекресток</title>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="noyaca" name="robots"/>
# <meta content='Творог Danone мягкий 5% 170г - купить по цене 45.90 с доставкой на дом. Творог, сырки - доставим до порога Вашего дома или офиса! Интернет-магазин доставки продуктов. "Перекресток"- есть все что любите!' name="description"/>
# <meta content="" name="keywords"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="sVxrBSMnZsKl3BVQlvKzafnWnuMCRsyweuWiTWz9" name="csrf-token"/>
# <link href="/manifest.json" rel="manifest"/>
# ...

# %%
res =soup.find_all('table', class_="xf-catalog-popup__nav")

# %%
s = """<ul>
 <li>
 <a href="/catalog/dacha-i-gril">
                         Дача и гриль
                     </a>
 <ul>
 <li>
 <ul>"""

# %%
re.findall(r'<a href="(/catalog.*)">', str(res[0]))
# Out:
# ['/catalog/dacha-i-gril',
#  '/catalog/dacha-i-gril/shashlyk-i-gril',
#  '/catalog/dacha-i-gril/vse-dlya-sada',
#  '/catalog/dacha-i-gril/posuda',
#  '/catalog/dacha-i-gril/produkty',
#  '/catalog/dacha-i-gril/igry',
#  '/catalog/dacha-i-gril/gigiena',
#  '/catalog/dacha-i-gril/turizm-otdyh-na-prirode',
#  '/catalog/dacha-i-gril/meshki-dlya-musora',
#  '/catalog/skidki-mesyatsa',
#  '/catalog/skidki-mesyatsa/ryba-ikra-moreprodukty',
#  '/catalog/skidki-mesyatsa/ptitsa-myaso-delikatesy',
#  '/catalog/skidki-mesyatsa/moloko-syr-yaytsa',
#  '/catalog/skidki-mesyatsa/soki-vody-napitki',
#  '/catalog/skidki-mesyatsa/chay-kofe-sahar',
#  '/catalog/skidki-mesyatsa/sousy-orehi-konservy',
#  '/catalog/skidki-mesyatsa/hleb-sladosti-sneki',
#  '/catalog/skidki-mesyatsa/makarony-krupy-spetsii',
#  '/catalog/skidki-mesyatsa/zamorojennye-produkty',
#  '/catalog/skidki-mesyatsa/tovary-dlya-mam-i-detey',
#  '/catalog/skidki-mesyatsa/zootovary',
#  '/catalog/skidki-mesyatsa/dom-sad-kuhnya-avto',
# ...

# %%
katalog = [
    'bakaleya', 'bytovaya-himiya', 'zamorozhennye-produkty', 'kolbasa-kopchennosti-myasnye-delikatesy',
    'konditerskie-izdeliya', 'chay-kofe-kakao', 'hlebobulochnye-izdeliya', 'tovary-dlya-zhivotnyh',
    'tovary-dlya-detey', 'specialnoe-pitanie', 'sladosti-i-konfety', 'ryba-i-moreprodukty', 'napitki-soki-vody',
    'myaso-i-ptica', 'kulinariya', 'kosmetika-i-lichnaya-gigiena'
]

# %%
brands = []

url = "http://pyaterochkaakcii.ru/katalog/{katalog}?page={page}"
for category in katalog:
    for page in range(20):
        resp = req.get(url.format(katalog=category, page=page))
        if resp.status_code != 200:
            print('ОШИБКА СТАТУСА', page, category)
            break

        soup = BeautifulSoup(resp.text, 'lxml')
        res = soup.find_all(class_='name')
        if not res:
            print(f'Больше нет страниц для {category}, максимальная длина: {page}')
            break
        for name in res:
            pattern = r'"(\w{2,})"'
            brand = re.findall(pattern, name.text)
            if brand:
                brands.append(brand[0])
# Out:
# Больше нет страниц для bakaleya, максимальная длина: 6
# Больше нет страниц для bytovaya-himiya, максимальная длина: 3
# Больше нет страниц для zamorozhennye-produkty, максимальная длина: 3
# Больше нет страниц для kolbasa-kopchennosti-myasnye-delikatesy, максимальная длина: 3
# Больше нет страниц для konditerskie-izdeliya, максимальная длина: 2
# Больше нет страниц для chay-kofe-kakao, максимальная длина: 3
# Больше нет страниц для hlebobulochnye-izdeliya, максимальная длина: 2
# Больше нет страниц для tovary-dlya-zhivotnyh, максимальная длина: 3
# Больше нет страниц для tovary-dlya-detey, максимальная длина: 4
# Больше нет страниц для specialnoe-pitanie, максимальная длина: 2
# Больше нет страниц для sladosti-i-konfety, максимальная длина: 5
# Больше нет страниц для ryba-i-moreprodukty, максимальная длина: 3
# Больше нет страниц для napitki-soki-vody, максимальная длина: 5
# Больше нет страниц для myaso-i-ptica, максимальная длина: 2
# ...

# %%
np.unique(brands).shape
# Out:
# (384,)

# %%
pd.Series(np.unique(brands)).to_csv('data/brands_patorochka.csv', index=False)

# %%
s = """Баклажаны	1.2	0.1	7.1	24	3.3
Брюква	1.2	0.1	8.9	34	3.1
Кабачки	0.6	0.3	5.2	23	2.3
Капуста белокочанная	1.8	0.1	6.8	27	3
Капуста квашеная	1.8	0.1	4.4	19	4.1
Капуста брюссельская	4.8		8	43	4
Капуста кольраби	2.8		10.7	42	3
Капуста краснокочанная	0.8		7.6	24	3.4
Капуста цветная	2.5	0.3	5.4	30	2.2
Картофель	2	0.4	18.1	80	2
Картофель молодой	2.4	0.4	12.4	61	2
Картофель сладкий (батат)	2		14.6	61	3
Лук зелёный	1.3		4.6	19	3
Лук-порей	2		8.2	33	2.3
Лук репчатый	1.4		10.4	41	3.1
Морковь	1.3	0.1	9.3	34	3
Огурцы	0.8	0.1	3.8	14	2.4
Огурцы солёные	0.8	0.1	2.4	13	4
Пастернак (корень)	1.4	сл.	12.9	47	3.3
Патиссоны	0.6	0.1	5.4	19	3.1
Перец зелёный сладкий	1.3	сл.	7.2	26	3
Перец красный сладкий	1.3	сл.	7.2	27	3
Петрушка	3.7	0.4	9.5	49	3
Петрушка (корень)	1.5	0.6	11.8	53	3.3
Ревень (черешки)	0.7	0.1	4.3	16	3
Редис	1.2	0.1	4.6	21	3.1
Редька	1.9	0.2	8	35	3.4
Репа	1.5	сл.	6.7	27	4
Салат	1.5	0.2	3.1	17	2.3
Свекла	1.5	0.1	11.8	42	3
Сельдерей			3		3.1
Сельдерей (корень)	1.3	0.3	7.1	32	3.3
Спаржа	1.9	0.1	4.4	21	3
Томаты	1.1	0.2	5	23	2
Укроп	2.5	0.5	7.6	31	3.1
Хрен	2.5	0.4	10.4	44	3.4
Черемша	2.4	0.1	7.1	36	3.1
Чеснок	6.5		6	46	2.4
Шпинат	2.9	0.3	2.5	22	3
Щавель	1.5	сл.	4	19	2.4
Бахчевые
Арбуз	0.7	0.2	10.9	38	2.3
Дыня	0.6		10.3	38	2.4
Тыква	1	0.1	5.9	25	3.1
Фрукты
Абрикосы	0.9	0.1	10.8	41	2.4
Айва	0.6	0.5	9.8	40	3.4
Алыча	0.2		6.9	27	2.5
Ананас	0.4	0.2	10.6	49	2.1
Бананы	1.5	0.1	21.8	89	3
Вишня	0.8	0.5	11.3	52	2
Гранат	0.9		13.9	52	2.3
Крахмал кукурузный	1	0.6	85.2	359	
Патока кукурузная	сл.	0.3	88.3	311	
Пектин			89.6	42	
Порошок горчичный	37.1	11.1	5.9	271	
Мёд натуральный	0.8	0	80.3	314	1.2
Сахар-сырец	0	0	95.3	362	1.2
Сахар-песок	0	0	99.8	379	1.1
Сахар-рафинад	0	0	99.9	379	1.1
Соль поваренная	0	0	0	0	1
Уксус 3%-ный	0	0	0	0	2
Кондитерские изделия
Батончики на кондитерском жире	3.3	30.5	63.9	523	2
Драже ореховое	11.9	38.3	44.2	552	2.3
Драже фруктовое в шоколаде	3.7	10.2	76.3	389	2.3
Ирис полутвердый	3.3	7.5	81.8	395	2
Карамель леденцовая	сл.	0.1	95	370	2
Карамель фруктовая	0.1	0.1	92.2	357	2
Карамель с ликёром	сл.	0.1	92.6	358	2.1
Карамель шоколадно-ореховая	1.8	9.2	86.8	420	2.3
Конфеты молочные	2.7	4.3	82.3	364	2
Конфеты помадные	2.2	4.6	83.6	369	2
Конфеты грильяжные	5.3	26.9	65.6	523	2
Конфеты кремовые	7.5	31.8	55.8	523	2
Конфеты фруктовые	1.6	8.6	75.8	369	2
Конфеты шоколадные	4	39.5	54.2	569	2
Зефир	0.8	сл.	78.5	304	2
Мармелад фруктово-ягодный	0.4	сл.	76.6	293	2
Пастила	0.5	сл.	80.8	310	2.2
Халва подсолнечная	11.6	29.7	54	523	3.3
Халва тахинная	12.7	29.9	50.6	516	3.3
Шоколад без добавлений	5.4	35.3	56.5	544	2
Шоколад молочный	6.9	35.7	54.4	550	2
Шоколад с орехами	6.6	40.9	49.9	580	2.3
Вафли с фруктовой начинкой	3.2	2.8	80.9	350	2.3
Вафли с жирной начинкой	3.4	30.2	64.7	539	3
Пирожное крошковое	6.1	23.8	51.6	438	3
Пирожное миндальное	8.5	16.2	66.2	431	3
Пирожное фруктовое	5.1	18.5	63.4	435	3.3
Пирожное слоёное с кремом	5.4	38.6	46.4	555	4
Пирожное трубочка с кремом	5.9	10.2	55.2	329	4
Торт с фруктовой начинкой	4.7	20	49.8	391	3.3
Торт слоёный с кремом	5	37.4	44	533	4
Молочные продукты
Молоко козье (сырое)	3	4.2	4.5	68	1.4
Молоко коровье (сырое)	3.2	3.6	4.8	64	1.3
Молоко коровье (стерил.)	2.9	4.7	4.7	61	2
Молоко коровье (паст.)	2.8	3.2	4.7	58	2
Молоко обезжиренное	2	0.05	4.8	31	1.5
Молоко топленое	3	6	4.7	84	2
Молоко сгущеное (с сахаром)	7.2	8.5	56	320	4
Какао со сгущ. молоком	8.2	7.5	54.9	309	4
Кофе со сгущ. молоком	8.4	8.6	53	312	4
Молоко сгущеное (стерил.)	7	8.3	9.5	140	3
Молоко сухое цельное	26	25	37.5	476	2.3
Сливки 10% жирности	3	10	4	118	2.3
Сливки 20% жирности	2.8	20	3.7	206	2.4
Сливки 35% жирности	2.5	35	3	337	3
Сливки взбитые плодовые	2.8	27	23.6	344	2.4
Сливки взбитые с шоколадом	2.8	27	21.6	337	3
Сливки сгущ. с сахаром	8	19	47	382	4
Сливки сухие	23	42.7	26.3	579	2.4
Сливки сухие высокожирные	10	75	10	753	3
Сметана 10% жирности	3	10	2.9	115	2.3
Сметана 20% жирности	2.8	20	3.2	206	2.4
Сметана 30% жирности	2.4	30	3.1	294	2.5
Сметана 40% жирности	2.4	40	2.6	381	3
Творог нежирный	18	0.6	1.8	88	2.4
Творог полужирный	16.7	9	2	159	2.5
Творог жирный	14	18	2.8	232	2.5
Творог мягкий диетический	16	11	1	170	2.4
Творожная масса сладкая	11.3	20	15.4	286	2.5
Сырки масса творожная	7.1	23	27.5	341	2.5
Сырки творожные детские	9.1	23	18.5	315	2.4
Сырки глазированные	8.5	27.8	32	407	3
Паста ацидофильная сладкая	6.6	8	25.5	198	2.5
Паста ацидофильная нежирная	5.5	0.2	12.5	74	2.4
Ацидофилин	2.8	3.2	3.8	57	2
Йогурт	5	3.2	3.8	66	2
Йогурт сладкий	5	3.2	8.5	85	2.2
Кефир жирный	2.8	3.2	4.1	56	2
Кефир нежирный	3	0.05	3.8	30	1.4
Кумыс из кобыльего молока	2.05	1	5	48	2
Кумыс из коровьего молока	3	0.05	6.3	40	2
Пахта пастеризованная	3.3	1	4.7	40	2.1
Пахта сквашенная	3.3	1	3.8	39	1.5
Простокваша	2.8	3.2	4.1	58	1.4
Простокваша Мечниковская	2.8	6	4	83	1.5
Ряженка 6% жирности	3	6	4.1	84	2
Сыворотка творожная	0.8	0.2	3.5	20	1.3
Сыворотка подсырная	1	0.1	4	21	1.3
Брынза из коровьего молока	17.9	20.1		260	3
Брынза из овечьего молока	14.6	25.5		298	3
Сыр "Вырусский"	29	15		258	3.2
Сыр "Голландский"	26	26.8		352	3.2
Сыр "Пошехонский"	26	26.5		350	3.2
Сыр "Прибалтийский"	30	9		209	3.2
Сыр "Российский"	23	29		360	3.2
Сыр "Рокфор"	20	28		337	3.4
Сыр плавленый "Российский"	22	27		340	3.2
Сыр колбасный копчёный	23	19		271	3.4
Мороженое молочное	3.2	3.5	21.3	126	2.3
Мороженое сливочное	3.3	10	19.8	179	2.3
Пломбир	3.2	15	20.8	227	2.4
Эскимо	3.5	20	19.6	270	2.4
Молочное шоколадное	4.2	3.5	23	138	2.3
Сливочное шоколадное	3.5	10	21.5	188	2.4
Пломбир шоколадный	3.6	15	22.3	236	2.4
Молочное крем-брюле	3.5	3.5	23.1	134	2.3
Сливочное крем-брюле	3.5	10	21.6	186	2.4
Пломбир крем-брюле	3	15	23	235	2.4
Молочное ореховое	5.4	6.5	20.1	157	2.4
Сливочное ореховое	5.5	13	18.6	210	2.5
Пломбир ореховый	5.2	18	19.9	259	2.5
Молочное клубничное	3.8	2.8	22.2	123	2.3
Сливочное клубничное	3.8	8	20.9	165	2.3
Мясные продукты
Мясо кролика	21.1	11		183	3.1
Мясо поросят	20.6	3		109	3.1
Телятина 1 категории	19.7	2		97	3.1
Баранина 1 категории	15.6	16.3		209	3.3
Баранья грудинка	14	25.8		288	3.3
Баранья корейка	15.9	21.5		255	3.3
Баранья тазобедренная часть	17	14.4		198	3.3
Буйволятина 1 категории	19	13.2		195	3.3
Верблюжатина 1 категории	18.9	13.3		160	3.3
Говядина 1 категории	18.6	16		218	3.3
Говяжья вырезка	20.2	2.8		106	3.3
Говяжья грудинка	16.3	18.7		233	3.3
Говяжья тазобедренная часть	20.4	2.5		104	3.3
Вымя говяжье	12.3	13.7		175	3.3
Печень говяжья	17.9	3.7		105	3.1
Почки говяжьи	15.2	2.8		86	3.1
Сердце говяжье	16	3.5		96	3.1
Язык говяжий	16	12.1		173	3.3
Оленина 1 категории	19.5	8.5		155	3.3
Свинина мясная	14.3	33		357	4
Свинина жирная	11.7	49.3		491	4.3
Свинина вырезка	19.4	7.1		142	3.3
Свинина грудинка	8	63.3		602	4.3
Свинина корейка	13.7	36.5		384	4.3
Свиная тазобедренная часть	15	27.2		305	4
Свиные ножки	23.5	15.6		234	4
Печень свиная	18.8	3.8		109	3.1
Язык свиной	15.9	16		208	3.3
Шпик свиной (без шкурки)	1.4	92.8		841	4.3
Шпик свиной солёный	1.4	90		816	4.3
Мясо яка	20	3.5		112	3.3
Колбаса вареная диабетическая	12.1	22.8		254	3
Колбаса вареная докторская	12.8	22.2	1.5	257	3
Колбаса вареная телячья	13.8	28.3		310	3
Колбаса вареная чайная	11.7	18.4	1.9	216	3
Колбаса в/копчёная любительская	17.3	39		309	3.5
Колбаса п/копчёная краковская	16.2	44.6		466	4
Колбаса п/копчёная украинская	16.5	34.4		376	4
Охотничьи колбаски п/копчёные	25.7	40		463	4
Колбаса сырокопченая зернистая	9.9	63.2		608	4.2
Колбаса сырокопченая сервелат	24	40.5		461	4.2
Ветчина особая	17.6	6.2		126	3.4
Мясной хлеб ветчинный	12.9	21.8	2	256	3.5
Ветчина из свинины в форме	22.6	20.9		279	4
Грудинка свиная копчено-запеченная	10	52.7		514	4.3
Грудинка свиная сырокопченая	8.9	63.3		605	4.3
Корейка свиная сырокопченая	10.2	47.4		475	4.3
Окорок свиной вареный	14.3	25.6		288	4
Сардельки говяжьи	11.4	18.2	1.5	215	3
Сардельки свиные	10.1	31.6	1.9	332	3.3
Сосиски любительские	9	29.5	0.7	226	3
Сосиски молочные	11	23.9	1.6	266	3
Говядина в собственном соку	24.5	16.6		247	3.3
Говядина тушеная	16.8	17		220	3.3
Завтрак туриста (говядина)	20.5	10.4		196	3.3
Колбасный фарш отдельный	13.6	23.7	2.9	279	3.1
Свинина тушеная	14.9	32.2		349	3.3
Фарш свиной сосисочный	10.6	20.4	4.4	244	3.1
Паштет мясной	16.4	23.3	0.4	277	3
Паштет печёночный	11.6	28.9	2.5	317	3
Пельмени мясные	10.7	15.5	16.3	255	3.3
Птица
Гуси 1 категории	15.2	39		412	3.4
Индейки 1 категории	19.5	22		276	3.3
Куры 1 категории	18.2	18.4	0.7	241	3.2
Перепёлки 1 категории	18.2	17.3	0.4	230	3.2
Утки 1 категории	15.8	38		405	3.3
Окорочек куриный	21.3	11	0.1	185	3.2
Филе куриное	23.6	1.9	0.4	113	3.2
Желудок куриный	21	6.4	0.6	130	3.2
Печень куриная	20.4	5.9	1.4	140	3.2
Сердце куриное	15.8	10.3	0.8	159	3.2
Яйцо куриное	12.7	11.5	0.7	157	2.2
Яйцо куриное (белок)	11.1				2.2
Яйцо куриное (желток)	16.2	31.2	1	352	2.2
Яйцо перепелиное	11.9	13.1	0.6	168	2.2
Яичный порошок	46	37.3	4.5	542	
Колбаса вареная подмосковская	17.2	11.6	1.8	180	3.2
Курица в собственном соку	23.2	9.9	0.4	184	3.2
Фарш колбасный куриный	13.9	14.9	1.4	193	3
Рыба и морепродукты
Вобла свежая	18	2.6		95	3.1
Вобла холодного копчения	31.1	6.3		181	4.3
Вобла каспийская вяленая	46.4	5.5		235	4.3
Горбуша	21	7		147	3.1
Горбуша солёная	22.1	9		169	4
Карп	16	5.3		112	3.1
Килька балтийская	17.1	7.6		137	4
Килька балтийская солёная	17.1	7.6		137	4.3
Килька горячего копчения	21.3	8.5		162	3.1
Лещ	17.1	4.1		105	3.1
Лещ морской	21.3	6.4		143	3.1
Лещ каспийский солёный	25.2	4.8		144	4
Лещ каспийский вяленый	42	5.9		221	4.3
Лещ горячего копчения	32.8	4.5		172	4.3
Лещ холодного копчения	26.7	4.6		160	4.3
Минтай	15.9	0.9		104	3.1
Мойва весенняя	13.1	7.1		116	3.1
Мойва осенняя	13.6	18.1		217	3.1
Окунь речной	18.5	0.9		103	3.1
Окунь морской свежий	18.2	3.3		220	3.1
Окунь морской гор. копчения	23.5	9		175	4.3
Окунь холодного копчения(балычок)	26.4	10.4		199	4.3
Осетр	16.4	10.9		82	3.1
Балык осетровый вяленый	21.6	10.1		177	4.3
Балык осетровый холодного копчения	20.4	12.5		194	4.3
Пикша	17.2	0.2		71	3.1
Сайра крупная	18.6	20.8		262	3.1
Сайра мелкая	20.4	7		143	3.1
Сельдь жирная свежая	17.7	19.5		246	3.1
Сельдь нежирная свежая	19.1	6.5		135	4.1
Сельдь атлантическая солёная	17	8.5		145	4
Скумбрия атлантическая	18	13.2		191	3.1
Снеток солено-сушеный	46.3	8.8		264	4.1
Ставрида океаническая	18.5	4.5		114	3.1
Ставрида хол. копчения	17.1	2.8		94	4.3
Судак	18.4	1.1		84	3.1
Треска	16	0.6		69	3.1
Треска солёная	23.1	0.6		98	4
Треска горячего копчения	26	1.2		115	4.3
Тунец	24.4	4.3		136	3.1
Угорь	14.5	30.5		333	3.1
Щука	18.4	1.1		84	3.1
Кальмар (мясо)	18	4.2		110	2.3
Краб камчатский (мясо)	16	3.6		96	2.3
Креветка (мясо)	18.9	2.2		95	2.3
Моллюск рапана	16.7	1.1		77	2.1
Мидии	9.1	1.5		50	2.1
Мясо ластоногих	24.5	1.54		113	3.1
Морская капуста	0.9	0.2	3	5	2
Икра горбуши зернистая	31.2	11.7		230	2.3
Икра кеты зернистая (красная)	31.6	13.8		251	2.3
Икра минтаевая пробойная	28.4	1.9		131	2.3
Икра осетровая зернистая	28.9	9.7		203	2.3
Икра осетровая паюсная	36	10.2		236	2.3
Килька пряного посола	15.1	8.9		141	3.3
Консервы "Морская капуста"	1	0.2	0.8	8	2.3
560Консервы натуральные "креветки"	17.8	1.1		81	3
Консервы натуральные "крабы"	18.7	1.1		85	3
Консервы "Печень трески"	4.2	65.7	1.2	613	3
Консервы натуральные "Горбуша"	20.9	5.8		136	3
Консервы натуральные "Скумбрия"	16.4	21.4		258	3
Консервы "Ставрида в масле"	15.6	27.4		309	3.3
Консервы "Треска в масле"	20.7	22.9		289	3.3
Консервы в масле "Шпроты"	17.4	32.4	0.4	363	3.3
Консервы "Горбуша в томате"	14.5	5.1	6.9	132	3
Консервы "Ставрида в томате"	14.8	2.3	7.3	110	3
Консервы "Судак в томате"	14	5.3	3.7	119	3
Паста"Океан"	13.6	4.2		92	3
Масла и жиры
Масло крестьянское несолёное	0.8	72.5	1.3	661	3.2
Масло крестьянское солёное		0.8	71	647	3.3
Масло сливочное несолёное	0.5	82.5	0.8	748	3.2
Масло бутербродное	2.5	61.5	1.7	566	3.2
Масло топленое	0.3	98	0.6	887	3.2
Масло кукурузное	0	99.9	0	899	3.2
Масло кунжутное	0	99.9	0	899	3.2
Масло оливковое	0	99.8	0	898	3.2
Масло подсолнечное	0	99.9	0	899	3.2
Масло соевое	0	99.9	0	899	3.2
Майонез "Провансаль"	3.1	67	2.6	624	3.2
Майонез столовый молочный	2.4	67	3.9	627	3.2
Маргарин столовый молочный	0.3	82	1	743	3.2
Маргарин "Экстра"	0.5	82	1	744	3.2
Жир кулинарный "Прима"	0	99.7	0	897	4
Жир кондитерский	0	99.7	0	897	4
Жир бараний топленый	0	99.7	0	897	4
Жир свиной топленый	0	99.7	0	897	4
Жир говяжий топленый	0	99.7	0	897	4
Жир тресковый	0	100	0	900	3.4
Напитки
Лимонад цитрусовый		0	7.5	31	1
Лимонад плодовоягодный		0	9.5	40	1
Пиво жигулевское 2.8% об.	0.6	0	4.8	37	1.3
Пиво "Портер" 5%об.	1.1	0	8.3	64	1.3
Квас хлебный 0.8% об.	0.2	0	5	25	1.2
Вино столовое белое 11% об.	0.2	0	0.2	65	1.3
Вино столовое красное 12% об.	0.3	0	0.2	71	1.3
Вино десертное белое 16% об.	0.5	0	16	153	1.3
Шампанское полусухое 12%об.	0.2	0	5	88	1.3
Водка 40%об.	0	0	0.1	235	1.3
Коньяк "3 звёздочки" 40%об.	0	0	1.5	239	1.3
Настойка "Старка" 43%об.	0	0	0.9	255	1.3
Наливка "Сливянка" 18%об.	0	0	30	216	1.3
Ликёр "Вишнёвый" 25%об	0	0	45	313	1.4
Пунш "Чёрносмородиновый"17%об	0	0	39	244	1.4
Чай черный байховый	20	5.1	15	99	
Кофе жареный в зернах	13.9	14.4	15.6	223	
Кофе растворимый	15	3.6		199	"""

# %%
products = []

# %%
for pord in s.split('\n'):
    products.append(pord[:pord.find('\t')].lower())

# %%
products = np.unique(products)

# %%
for i in products:
    if i.startswith('мол'):
        print(i)
# Out:
# моллюск рапана
# молоко козье (сырое)
# молоко коровье (паст.)
# молоко коровье (стерил.)
# молоко коровье (сырое)
# молоко обезжиренное
# молоко сгущеное (с сахаром)
# молоко сгущеное (стерил.)
# молоко сухое цельное
# молоко топленое
# молочное клубничное
# молочное крем-брюле
# молочное ореховое
# молочное шоколадное
# молочные продукт
